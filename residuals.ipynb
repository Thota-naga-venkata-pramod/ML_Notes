# %% [markdown]
# <a href="https://colab.research.google.com/github/Thota-naga-venkata-pramod/ML_Notes/blob/me/residuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Resudials![Residuals.png](data:image/png;base64,...)
#
# The residual for each observation is the difference between predicted values of
# y(dependent variable) and observed values of y
#
# Residual=actual y value−predicted y value,
# ri=yi−y^i.
#
# Having a negative residual means that the predicted value is too high, similarly if you have a positive residual it means that the predicted value was too low. The aim of a regression line is to minimise the sum of residuals.
